# %% [markdown]
# <a href="https://colab.research.google.com/github/AustinYYY/docs-content/blob/main/Python_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab
#
# Run a cell: "play" button or Ctrl+Enter
#
# For running one or more highlighted rows, Ctrl+Shift+Enter

# %% [markdown]
# # Python Introduction

# %%
#For accessing unix terminal
# !python --version
# !ls

#Python code and bash command can co-exist in the same cell
# Out:
# Python 3.12.12
# sample_data

# %%
print("Hello world!!")
# Out:
# Hello world!!

# %% [markdown]
# Python doesn't need explicit declaration of variables. Assigning a value to a variable is sufficient also for the declaration.

# %%
test = 9

# %%
print(test)
# Out:
# 9

# %%
a = 56 + 9
a = a + test
print(a)
# Out:
# 74

# %% [markdown]
# For printing variable's content:

# %%
test
# Out:
# 9

# %% [markdown]
# Or with the "print" function:

# %%
print(test)
# Out:
# 9

# %% [markdown]
# ## Python functions in Colab
# Usually, a function must be included in the .py file or in a .py file called through the "import" command.
# In Colab, running a cell containing the function is sufficient for that function to be available to be called.

# %%
def Example_Function():

  print("This is a function")
  print("hi")
  return 0 , 1 ,3
zero, one , three = Example_Function()
# Out:
# This is a function
# hi
